# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import xgboost as xgb
from xgboost import plot_importance
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
import tensorflow as tf
from sklearn.preprocessing import StandardScaler

# %% [markdown]
# ## Preprocess data

# %%
df = pd.read_csv('gym_members_exercise_tracking.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 15 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Age                            973 non-null    int64
#  1   Gender                         973 non-null    object
#  2   Weight (kg)                    973 non-null    float64
#  3   Height (m)                     973 non-null    float64
#  4   Max_BPM                        973 non-null    int64
#  5   Avg_BPM                        973 non-null    int64
#  6   Resting_BPM                    973 non-null    int64
#  7   Session_Duration (hours)       973 non-null    float64
#  8   Calories_Burned                973 non-null    float64
#  9   Workout_Type                   973 non-null    object
#  10  Fat_Percentage                 973 non-null    float64
#  11  Water_Intake (liters)          973 non-null    float64
#  12  Workout_Frequency (days/week)  973 non-null    int64
#  13  Experience_Level               973 non-null    int64
#  14  BMI                            973 non-null    float64
# dtypes: float64(7), int64(6), object(2)
# memory usage: 114.2+ KB

# %%
#Remove not important features

df1 = df.drop(columns = ['Weight (kg)', 'Height (m)', 'Resting_BPM', 'Experience_Level'])
df1
# Out:
#      Age  Gender  Max_BPM  Avg_BPM  Session_Duration (hours)  Calories_Burned  \
# 0     56    Male      180      157                      1.69           1313.0
# 1     46  Female      179      151                      1.30            883.0
# 2     32  Female      167      122                      1.11            677.0
# 3     25    Male      190      164                      0.59            532.0
# 4     38    Male      188      158                      0.64            556.0
# ..   ...     ...      ...      ...                       ...              ...
# 968   24    Male      187      158                      1.57           1364.0
# 969   25    Male      184      166                      1.38           1260.0
# 970   59  Female      194      120                      1.72            929.0
# 971   32    Male      198      146                      1.10            883.0
# 972   46    Male      166      146                      0.75            542.0
#
#     Workout_Type  Fat_Percentage  Water_Intake (liters)  \
# 0           Yoga            12.6                    3.5
# 1           HIIT            33.9                    2.1
# 2         Cardio            33.4                    2.3
# 3       Strength            28.8                    2.1
# 4       Strength            29.2                    2.8
# ..           ...             ...                    ...
# 968     Strength            10.0                    3.5
# 969     Strength            25.0                    3.0
# 970       Cardio            18.8                    2.7
# 971         HIIT            28.2                    2.1
# 972     Strength            28.8                    3.5
#
#      Workout_Frequency (days/week)    BMI
# 0                                4  30.20
# 1                                4  32.00
# 2                                4  24.71
# 3                                3  18.41
# 4                                3  14.39
# ..                             ...    ...
# 968                              4  28.77
# 969                              2  25.69
# 970                              5  19.50
# 971                              3  37.74
# 972                              2  33.38
#
# [973 rows x 11 columns]

# %%
#Make age groups

df1['Age'].unique()
# Out:
# array([56, 46, 32, 25, 38, 36, 40, 28, 41, 53, 57, 20, 39, 19, 47, 55, 50,
#        29, 42, 44, 59, 45, 33, 54, 24, 26, 35, 21, 31, 43, 37, 52, 34, 23,
#        51, 27, 48, 58, 18, 22, 30, 49], dtype=int64)

# %%
#Make age groups

df1['Age_Group'] = pd.cut(df['Age'], bins = [10, 20, 30, 40, 50, 60],
                         right = False,
                         labels = ['10s', '20s', '30s', '40s', '50s'])

# %%
#Drop 'Age' feature

df2 = df1.drop(columns = ['Age'])
df2
# Out:
#      Gender  Max_BPM  Avg_BPM  Session_Duration (hours)  Calories_Burned  \
# 0      Male      180      157                      1.69           1313.0
# 1    Female      179      151                      1.30            883.0
# 2    Female      167      122                      1.11            677.0
# 3      Male      190      164                      0.59            532.0
# 4      Male      188      158                      0.64            556.0
# ..      ...      ...      ...                       ...              ...
# 968    Male      187      158                      1.57           1364.0
# 969    Male      184      166                      1.38           1260.0
# 970  Female      194      120                      1.72            929.0
# 971    Male      198      146                      1.10            883.0
# 972    Male      166      146                      0.75            542.0
#
#     Workout_Type  Fat_Percentage  Water_Intake (liters)  \
# 0           Yoga            12.6                    3.5
# 1           HIIT            33.9                    2.1
# 2         Cardio            33.4                    2.3
# 3       Strength            28.8                    2.1
# 4       Strength            29.2                    2.8
# ..           ...             ...                    ...
# 968     Strength            10.0                    3.5
# 969     Strength            25.0                    3.0
# 970       Cardio            18.8                    2.7
# 971         HIIT            28.2                    2.1
# 972     Strength            28.8                    3.5
#
#      Workout_Frequency (days/week)    BMI Age_Group
# 0                                4  30.20       50s
# 1                                4  32.00       40s
# 2                                4  24.71       30s
# 3                                3  18.41       20s
# 4                                3  14.39       30s
# ..                             ...    ...       ...
# 968                              4  28.77       20s
# 969                              2  25.69       20s
# 970                              5  19.50       50s
# 971                              3  37.74       30s
# 972                              2  33.38       40s
#
# [973 rows x 11 columns]

# %%
#Look for null

df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 973 entries, 0 to 972
# Data columns (total 11 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Gender                         973 non-null    object
#  1   Max_BPM                        973 non-null    int64
#  2   Avg_BPM                        973 non-null    int64
#  3   Session_Duration (hours)       973 non-null    float64
#  4   Calories_Burned                973 non-null    float64
#  5   Workout_Type                   973 non-null    object
#  6   Fat_Percentage                 973 non-null    float64
#  7   Water_Intake (liters)          973 non-null    float64
#  8   Workout_Frequency (days/week)  973 non-null    int64
#  9   BMI                            973 non-null    float64
#  10  Age_Group                      973 non-null    category
# dtypes: category(1), float64(5), int64(3), object(2)
# memory usage: 77.3+ KB

# %%
#Look for outliers

plt.figure(figsize = (10, 6))

for col in [['Max_BPM', 'Avg_BPM']]:
    sns.boxplot(df2[col])
    plt.xlabel('Features')
    plt.title(f'Box Plots of {col}')
    plt.show()

# %%
#Look for outliers

plt.figure(figsize = (10, 6))

for col in [['Session_Duration (hours)', 'Water_Intake (liters)']]:
    sns.boxplot(df2[col])
    plt.xlabel('Features')
    plt.title(f'Box Plots of {col}')
    plt.show()

# %%
#Look for outliers

plt.figure(figsize = (8, 6))

for col in ['Calories_Burned']:
    sns.boxplot(df2[col])
    plt.xlabel('Feature')
    plt.title(f'Box Plots of {col}')
    plt.show()

# %%
#Look for outliers

plt.figure(figsize = (10, 6))

for col in [['Fat_Percentage', 'BMI']]:
    sns.boxplot(df2[col])
    plt.xlabel('Features')
    plt.title(f'Box Plots of {col}')
    plt.show()

# %%
#Remove outliers ('Calories_Burned')

q1 = df2['Calories_Burned'].quantile(0.25)
q3 = df2['Calories_Burned'].quantile(0.75)

iqr = q3 - q1

lower_limit = q1 - 1.5*iqr
upper_limit = q3 + 1.5*iqr

condition1 = df2['Calories_Burned'] >= lower_limit
condition2 = df2['Calories_Burned'] <= upper_limit

df3 = df2[condition1 & condition2]

df3
# Out:
#      Gender  Max_BPM  Avg_BPM  Session_Duration (hours)  Calories_Burned  \
# 0      Male      180      157                      1.69           1313.0
# 1    Female      179      151                      1.30            883.0
# 2    Female      167      122                      1.11            677.0
# 3      Male      190      164                      0.59            532.0
# 4      Male      188      158                      0.64            556.0
# ..      ...      ...      ...                       ...              ...
# 968    Male      187      158                      1.57           1364.0
# 969    Male      184      166                      1.38           1260.0
# 970  Female      194      120                      1.72            929.0
# 971    Male      198      146                      1.10            883.0
# 972    Male      166      146                      0.75            542.0
#
#     Workout_Type  Fat_Percentage  Water_Intake (liters)  \
# 0           Yoga            12.6                    3.5
# 1           HIIT            33.9                    2.1
# 2         Cardio            33.4                    2.3
# 3       Strength            28.8                    2.1
# 4       Strength            29.2                    2.8
# ..           ...             ...                    ...
# 968     Strength            10.0                    3.5
# 969     Strength            25.0                    3.0
# 970       Cardio            18.8                    2.7
# 971         HIIT            28.2                    2.1
# 972     Strength            28.8                    3.5
#
#      Workout_Frequency (days/week)    BMI Age_Group
# 0                                4  30.20       50s
# 1                                4  32.00       40s
# 2                                4  24.71       30s
# 3                                3  18.41       20s
# 4                                3  14.39       30s
# ..                             ...    ...       ...
# 968                              4  28.77       20s
# 969                              2  25.69       20s
# 970                              5  19.50       50s
# 971                              3  37.74       30s
# 972                              2  33.38       40s
#
# [963 rows x 11 columns]

# %%
#Remove outliers ('BMI')

q1 = df3['BMI'].quantile(0.25)
q3 = df3['BMI'].quantile(0.75)

iqr = q3 - q1

lower_limit = q1 - 1.5*iqr
upper_limit = q3 + 1.5*iqr

condition1 = df3['BMI'] >= lower_limit
condition2 = df3['BMI'] <= upper_limit

df4 = df3[condition1 & condition2]

df4
# Out:
#      Gender  Max_BPM  Avg_BPM  Session_Duration (hours)  Calories_Burned  \
# 0      Male      180      157                      1.69           1313.0
# 1    Female      179      151                      1.30            883.0
# 2    Female      167      122                      1.11            677.0
# 3      Male      190      164                      0.59            532.0
# 4      Male      188      158                      0.64            556.0
# ..      ...      ...      ...                       ...              ...
# 968    Male      187      158                      1.57           1364.0
# 969    Male      184      166                      1.38           1260.0
# 970  Female      194      120                      1.72            929.0
# 971    Male      198      146                      1.10            883.0
# 972    Male      166      146                      0.75            542.0
#
#     Workout_Type  Fat_Percentage  Water_Intake (liters)  \
# 0           Yoga            12.6                    3.5
# 1           HIIT            33.9                    2.1
# 2         Cardio            33.4                    2.3
# 3       Strength            28.8                    2.1
# 4       Strength            29.2                    2.8
# ..           ...             ...                    ...
# 968     Strength            10.0                    3.5
# 969     Strength            25.0                    3.0
# 970       Cardio            18.8                    2.7
# 971         HIIT            28.2                    2.1
# 972     Strength            28.8                    3.5
#
#      Workout_Frequency (days/week)    BMI Age_Group
# 0                                4  30.20       50s
# 1                                4  32.00       40s
# 2                                4  24.71       30s
# 3                                3  18.41       20s
# 4                                3  14.39       30s
# ..                             ...    ...       ...
# 968                              4  28.77       20s
# 969                              2  25.69       20s
# 970                              5  19.50       50s
# 971                              3  37.74       30s
# 972                              2  33.38       40s
#
# [938 rows x 11 columns]

# %% [markdown]
# ## EDA

# %%
#Look into correlations

df_for_corr = df4.drop(columns = ['Gender', 'Workout_Type', 'Age_Group'])

cor_matrix = df_for_corr.corr()

cor_matrix
# Out:
#                                 Max_BPM   Avg_BPM  Session_Duration (hours)  \
# Max_BPM                        1.000000 -0.049386                  0.011077
# Avg_BPM                       -0.049386  1.000000                 -0.011948
# Session_Duration (hours)       0.011077 -0.011948                  1.000000
# Calories_Burned               -0.000265  0.314442                  0.908394
# Fat_Percentage                -0.004490  0.025114                 -0.572470
# Water_Intake (liters)          0.020063 -0.025729                  0.275757
# Workout_Frequency (days/week) -0.031542 -0.030948                  0.640863
# BMI                            0.083471 -0.011495                  0.009518
#
#                                Calories_Burned  Fat_Percentage  \
# Max_BPM                              -0.000265       -0.004490
# Avg_BPM                               0.314442        0.025114
# Session_Duration (hours)              0.908394       -0.572470
# Calories_Burned                       1.000000       -0.582186
# Fat_Percentage                       -0.582186        1.000000
# Water_Intake (liters)                 0.344877       -0.588672
# Workout_Frequency (days/week)         0.570688       -0.529603
# BMI                                   0.055451       -0.113197
#
#                                Water_Intake (liters)  \
# Max_BPM                                     0.020063
# Avg_BPM                                    -0.025729
# Session_Duration (hours)                    0.275757
# Calories_Burned                             0.344877
# Fat_Percentage                             -0.588672
# Water_Intake (liters)                       1.000000
# Workout_Frequency (days/week)               0.229580
# BMI                                         0.211108
#
#                                Workout_Frequency (days/week)       BMI
# Max_BPM                                            -0.031542  0.083471
# Avg_BPM                                            -0.030948 -0.011495
# Session_Duration (hours)                            0.640863  0.009518
# Calories_Burned                                     0.570688  0.055451
# Fat_Percentage                                     -0.529603 -0.113197
# Water_Intake (liters)                               0.229580  0.211108
# Workout_Frequency (days/week)                       1.000000  0.000617
# BMI                                                 0.000617  1.000000

# %%
#Look into correlations

plt.figure(figsize = (10, 6))
sns.heatmap(cor_matrix, vmax = 1, vmin = -1, center = 0, fmt = '0.3f', annot = True, cmap = 'coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
#Session duration and calories burned

sns.set_theme(rc = {'figure.figsize' : (12, 6)})
sns.lineplot(data = df4, x = 'Session_Duration (hours)', y = 'Calories_Burned', errorbar = None)
plt.show()

# %%
#Avg_BPM and calories burned

sns.set_theme(rc = {'figure.figsize' : (12, 6)})
sns.lineplot(data = df4, x = 'Avg_BPM' ,y = 'Calories_Burned', errorbar = None)
plt.show()

# %%
#Water intake and calories burned

sns.set_theme(rc = {'figure.figsize' : (12, 6)})
sns.lineplot(data = df4, x = 'Water_Intake (liters)' ,y = 'Calories_Burned', errorbar = None)
plt.show()

# %%
#Workout type, workout frequency, and calories burned

group1 = df4.groupby(['Workout_Type','Workout_Frequency (days/week)']).agg({'Calories_Burned':'mean'})

group1
# Out:
#                                             Calories_Burned
# Workout_Type Workout_Frequency (days/week)
# Cardio       2                                   691.935484
#              3                                   820.471910
#              4                                  1004.902778
#              5                                  1238.565217
# HIIT         2                                   756.682927
#              3                                   827.609756
#              4                                   993.875000
#              5                                  1266.625000
# Strength     2                                   789.511111
#              3                                   798.230000
#              4                                   969.753086
#              5                                  1242.434783
# Yoga         2                                   691.782609
#              3                                   829.083333
#              4                                   982.853333
#              5                                  1271.740741

# %%
#Workout type, workout frequency, and calories burned

sns.set_theme(rc = {'figure.figsize' : (10, 6)}, font = 'Malgun Gothic', palette = 'muted')

bar_graph1 = sns.barplot(data = group1, x = 'Workout_Type', y = 'Calories_Burned', errorbar = None, hue = 'Workout_Frequency (days/week)')

sns.move_legend(bar_graph1, "lower right")

plt.show()

# %%
#Age group, workout type, and calories burned

group2 = df4.groupby(['Age_Group','Workout_Type']).agg({'Calories_Burned':'mean'})

group2
# Out:
#                         Calories_Burned
# Age_Group Workout_Type
# 10s       Cardio             850.888889
#           HIIT              1081.125000
#           Strength           946.307692
#           Yoga              1024.272727
# 20s       Cardio             951.690909
#           HIIT               899.166667
#           Strength           939.931034
#           Yoga               909.132075
# 30s       Cardio             869.746032
#           HIIT               964.604651
#           Strength           931.500000
#           Yoga               952.525000
# 40s       Cardio             898.654545
#           HIIT               951.928571
#           Strength           865.213115
#           Yoga               899.661765
# 50s       Cardio             816.054545
#           HIIT               826.785714
#           Strength           837.584615
#           Yoga               846.450000

# %%
#Age group, workout type, and calories burned

sns.set_theme(rc = {'figure.figsize' : (10, 6)}, font = 'Malgun Gothic', palette = 'muted')

bar_graph2 = sns.barplot(data = group2, x = 'Age_Group', y = 'Calories_Burned', errorbar = None, hue = 'Workout_Type')

sns.move_legend(bar_graph1, "lower right")

plt.show()

# %%
#Gender, workout type, and calories burned

group3 = df4.groupby(['Gender','Workout_Type']).agg({'Calories_Burned':'mean'})

group3
# Out:
#                      Calories_Burned
# Gender Workout_Type
# Female Cardio             828.472000
#        HIIT               869.953271
#        Strength           863.097561
#        Yoga               886.122642
# Male   Cardio             935.561983
#        HIIT               959.711538
#        Strength           923.142857
#        Yoga               917.357143

# %%
#Gender, workout type, and calories burned

sns.set_theme(rc = {'figure.figsize' : (10, 6)}, font = 'Malgun Gothic', palette = 'muted')

bar_graph3 = sns.barplot(data = group3, x = 'Gender', y = 'Calories_Burned', errorbar = None, hue = 'Workout_Type')

sns.move_legend(bar_graph1, "lower right")

plt.show()

# %% [markdown]
# ## Develop a calory prediction model_XGBoost

# %%
#XGBoost model -> Calory prediction

X = df4[['Avg_BPM', 'Session_Duration (hours)', 'Fat_Percentage', 'Water_Intake (liters)', 'Workout_Frequency (days/week)', 'BMI']]
y = df4['Calories_Burned']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

# %%
# pip install --upgrade xgboost scikit-learn

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_absolute_error

xgb_model = XGBRegressor(
    n_estimators=100,    
    max_depth=5,         
    gamma=0,              
    importance_type='gain',
    reg_lambda=1,        
    random_state=100
)

xgb_model.fit(X_train, y_train)

preds = xgb_model.predict(X_test)

mae = mean_absolute_error(y_test, preds)

print(f"MAE: {mae}")
# Out:
# MAE: 49.02550571522814

# %%
#XGBoost model -> model test

test_df = pd.DataFrame({'Avg_BPM' : [120], 
                        'Session_Duration (hours)' : [2], 
                        'Fat_Percentage' : [17], 
                        'Water_Intake (liters)' : [1],
                        'Workout_Frequency (days/week)' : [3],
                        'BMI' : [30]})

xgb_model.predict(test_df)
# Out:
# array([1081.3279], dtype=float32)

# %% [markdown]
# ## Develop a calory prediction model_Tensorflow regression

# %%
#Tensorflow regression model

tf.random.set_seed(42)

tf_model = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation = 'relu', name = 'layer_1'),
    tf.keras.layers.Dense(10, activation = 'relu', name = 'layer_2'),
    tf.keras.layers.Dense(1, name = 'output_layer')
])

tf_model.compile(loss = tf.keras.losses.mae, 
                 optimizer = tf.keras.optimizers.Adam(),
                 metrics = ['mae'])

# %%
train_history = tf_model.fit(X_train, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 880.5402 - mae: 880.5402
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 845.0499 - mae: 845.0499
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 798.0575 - mae: 798.0575
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 724.1552 - mae: 724.1552
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 608.1462 - mae: 608.1462
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 434.5843 - mae: 434.5843
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 256.5095 - mae: 256.5095
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 205.2520 - mae: 205.2520
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 206.0532 - mae: 206.0532
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 204.1606 - mae: 204.1606
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 203.7782 - mae: 203.7782
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 203.3077 - mae: 203.3077
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 202.5718 - mae: 202.5718
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 202.0954 - mae: 202.0954
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 201.3095 - mae: 201.3095
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 200.6047 - mae: 200.6047
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 199.9993 - mae: 199.9993
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 199.1205 - mae: 199.1205
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 198.1180 - mae: 198.1180
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 197.4326 - mae: 197.4326
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 196.7289 - mae: 196.7289
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 195.9193 - mae: 195.9193
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 195.1097 - mae: 195.1097
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 194.2020 - mae: 194.2020
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 193.2391 - mae: 193.2391
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 192.4035 - mae: 192.4035
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 191.6483 - mae: 191.6483
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 190.6034 - mae: 190.6034
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 189.7105 - mae: 189.7105
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 188.6273 - mae: 188.6273
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 187.6616 - mae: 187.6616
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 186.7285 - mae: 186.7285
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 185.2497 - mae: 185.2497
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 184.2329 - mae: 184.2329
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 183.0927 - mae: 183.0927
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 181.6970 - mae: 181.6970
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 180.8543 - mae: 180.8543
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 179.4759 - mae: 179.4759
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 178.1518 - mae: 178.1518
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 176.4641 - mae: 176.4641
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 175.2728 - mae: 175.2728
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 173.9305 - mae: 173.9305
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 172.2996 - mae: 172.2996
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 170.7768 - mae: 170.7768
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 169.2207 - mae: 169.2207
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 167.7984 - mae: 167.7984
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 165.9398 - mae: 165.9398
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 164.4668 - mae: 164.4668
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 162.6654 - mae: 162.6654
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 160.5869 - mae: 160.5869
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 159.3849 - mae: 159.3849
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 157.4671 - mae: 157.4671
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 155.6312 - mae: 155.6312
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 153.7748 - mae: 153.7748
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 152.2831 - mae: 152.2831
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 150.6468 - mae: 150.6468
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 149.5113 - mae: 149.5113
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 148.1285 - mae: 148.1285
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 146.7753 - mae: 146.7753
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 145.5668 - mae: 145.5668
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 144.7499 - mae: 144.7499
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 143.4528 - mae: 143.4528
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 142.7018 - mae: 142.7018
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 141.9169 - mae: 141.9169
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 140.9609 - mae: 140.9609
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 140.3963 - mae: 140.3963
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 139.6878 - mae: 139.6878
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 139.0896 - mae: 139.0896
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 138.5141 - mae: 138.5141
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 137.9044 - mae: 137.9044
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 137.5879 - mae: 137.5879
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 137.0576 - mae: 137.0576
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 136.7148 - mae: 136.7148
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 136.5096 - mae: 136.5096
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135.9115 - mae: 135.9115
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 135.4281 - mae: 135.4281
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135.5718 - mae: 135.5718
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 135.5621 - mae: 135.5621
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134.8847 - mae: 134.8847
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134.8896 - mae: 134.8896
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134.7066 - mae: 134.7066
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 134.2962 - mae: 134.2962
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133.6319 - mae: 133.6319
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133.6582 - mae: 133.6582
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 133.1240 - mae: 133.1240
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 133.4381 - mae: 133.4381
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 133.2050 - mae: 133.2050
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 132.7206 - mae: 132.7206
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 132.6397 - mae: 132.6397
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 132.4879 - mae: 132.4879
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 132.4400 - mae: 132.4400
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 131.8194 - mae: 131.8194
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131.9262 - mae: 131.9262
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131.6844 - mae: 131.6844
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131.1659 - mae: 131.1659
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 130.8536 - mae: 130.8536
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 131.0634 - mae: 131.0634
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 130.8521 - mae: 130.8521
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129.9479 - mae: 129.9479
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 130.4337 - mae: 130.4337
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 130.3152 - mae: 130.3152
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 129.9704 - mae: 129.9704
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129.7825 - mae: 129.7825
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129.6991 - mae: 129.6991
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 129.5203 - mae: 129.5203
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129.4452 - mae: 129.4452
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 129.1496 - mae: 129.1496
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 128.4432 - mae: 128.4432
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 128.8009 - mae: 128.8009
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 128.5901 - mae: 128.5901
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 128.4227 - mae: 128.4227
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 128.3598 - mae: 128.3598
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 128.0924 - mae: 128.0924
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 127.9131 - mae: 127.9131
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 127.7711 - mae: 127.7711
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 127.7787 - mae: 127.7787
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 127.4790 - mae: 127.4790
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 127.3192 - mae: 127.3192
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 126.8390 - mae: 126.8390
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126.9743 - mae: 126.9743
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 126.8008 - mae: 126.8008
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126.6202 - mae: 126.6202
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 126.3918 - mae: 126.3918
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 125.8108 - mae: 125.8108
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125.4615 - mae: 125.4615
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 125.9161 - mae: 125.9161
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125.7061 - mae: 125.7061
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125.1903 - mae: 125.1903
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125.3393 - mae: 125.3393
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 125.2753 - mae: 125.2753
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 125.0180 - mae: 125.0180
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124.9560 - mae: 124.9560
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124.8044 - mae: 124.8044
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124.4443 - mae: 124.4443
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 124.3346 - mae: 124.3346
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 124.1609 - mae: 124.1609
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 123.9864 - mae: 123.9864
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 123.7223 - mae: 123.7223
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 123.5768 - mae: 123.5768
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 123.4304 - mae: 123.4304
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 123.2579 - mae: 123.2579
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 122.9956 - mae: 122.9956
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 122.8552 - mae: 122.8552
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 122.5906 - mae: 122.5906
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 122.0775 - mae: 122.0775
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 122.2409 - mae: 122.2409
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 122.0761 - mae: 122.0761
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 121.9483 - mae: 121.9483
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 121.7050 - mae: 121.7050
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 121.5378 - mae: 121.5378
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 121.3276 - mae: 121.3276
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 121.2176 - mae: 121.2176
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 121.0200 - mae: 121.0200
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 120.8160 - mae: 120.8160
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 120.6202 - mae: 120.6202
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 120.4185 - mae: 120.4185
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 120.0757 - mae: 120.0757
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 119.9939 - mae: 119.9939
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 119.8416 - mae: 119.8416
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 119.5493 - mae: 119.5493
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 119.4962 - mae: 119.4962
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 119.1240 - mae: 119.1240
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 118.9111 - mae: 118.9111
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 118.7589 - mae: 118.7589
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 118.6867 - mae: 118.6867
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 118.2772 - mae: 118.2772
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 118.2561 - mae: 118.2561
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 117.9651 - mae: 117.9651
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 117.3580 - mae: 117.3580
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 117.6291 - mae: 117.6291
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 117.2523 - mae: 117.2523
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 117.1392 - mae: 117.1392
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 116.7376 - mae: 116.7376
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 116.6650 - mae: 116.6650
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 116.4885 - mae: 116.4885
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 116.2021 - mae: 116.2021
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 116.0186 - mae: 116.0186
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 115.6277 - mae: 115.6277
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 115.8843 - mae: 115.8843
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 115.6137 - mae: 115.6137
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 115.4587 - mae: 115.4587
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 114.8335 - mae: 114.8335
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 114.7196 - mae: 114.7196
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 114.4632 - mae: 114.4632
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 114.1127 - mae: 114.1127
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 113.8699 - mae: 113.8699
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 113.6308 - mae: 113.6308
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 113.3936 - mae: 113.3936
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 112.9919 - mae: 112.9919
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.9081 - mae: 112.9081
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.6351 - mae: 112.6351
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 112.3904 - mae: 112.3904
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 112.1396 - mae: 112.1396
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 112.0257 - mae: 112.0257
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 111.5139 - mae: 111.5139
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111.5909 - mae: 111.5909
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 111.4718 - mae: 111.4718
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 111.2238 - mae: 111.2238
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 111.0126 - mae: 111.0126
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 110.5858 - mae: 110.5858

# %%
tf_model.evaluate(X_test, y_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 106.4361 - mae: 106.4361
# [113.01057434082031, 113.01057434082031]

# %%
pd.DataFrame(train_history.history).plot()
plt.ylabel('loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %% [markdown]
# ## Develop a calory prediction model_Tensorflow regression (data standardization)

# %%
#Data standardization

standard_scaler = StandardScaler()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 5)

standard_scaler.fit(X_train)

X_train_standard = standard_scaler.transform(X_train)
X_test_standard = standard_scaler.transform(X_test)

# %%
tf.random.set_seed(42)

tf_model2 = tf.keras.Sequential([
    tf.keras.layers.Dense(100, activation = 'relu', name = 'layer_1'),
    tf.keras.layers.Dense(10, activation = 'relu', name = 'layer_2'),
    tf.keras.layers.Dense(1, name = 'output_layer')
])

tf_model2.compile(loss = tf.keras.losses.mae, 
              optimizer = tf.keras.optimizers.Adam(),
              metrics = ['mae'])

# %%
train_history = tf_model2.fit(X_train_standard, y_train, epochs = 200)
# Out:
# Epoch 1/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 892.8957 - mae: 892.8957
# Epoch 2/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 891.8031 - mae: 891.8031
# Epoch 3/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 889.0558 - mae: 889.0558
# Epoch 4/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 885.3840 - mae: 885.3840
# Epoch 5/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 879.6279 - mae: 879.6279
# Epoch 6/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 870.9235 - mae: 870.9235
# Epoch 7/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 858.3671 - mae: 858.3671
# Epoch 8/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 841.0197 - mae: 841.0197
# Epoch 9/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 817.9317 - mae: 817.9317
# Epoch 10/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 788.1500 - mae: 788.1500
# Epoch 11/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 750.6778 - mae: 750.6778
# Epoch 12/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 705.0673 - mae: 705.0673
# Epoch 13/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 650.0198 - mae: 650.0198
# Epoch 14/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 586.3618 - mae: 586.3618
# Epoch 15/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 516.5381 - mae: 516.5381
# Epoch 16/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 439.9211 - mae: 439.9211
# Epoch 17/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 372.1031 - mae: 372.1031
# Epoch 18/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 326.8044 - mae: 326.8044
# Epoch 19/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 296.9324 - mae: 296.9324
# Epoch 20/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 273.4825 - mae: 273.4825
# Epoch 21/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 253.4516 - mae: 253.4516
# Epoch 22/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 235.7766 - mae: 235.7766
# Epoch 23/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 218.9187 - mae: 218.9187
# Epoch 24/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 204.1369 - mae: 204.1369
# Epoch 25/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 191.8392 - mae: 191.8392
# Epoch 26/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 181.1703 - mae: 181.1703
# Epoch 27/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 171.1762 - mae: 171.1762
# Epoch 28/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 161.9034 - mae: 161.9034
# Epoch 29/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 153.1908 - mae: 153.1908
# Epoch 30/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 144.6885 - mae: 144.6885
# Epoch 31/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 136.7457 - mae: 136.7457
# Epoch 32/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 129.1180 - mae: 129.1180
# Epoch 33/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 121.9966 - mae: 121.9966
# Epoch 34/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 115.2590 - mae: 115.2590
# Epoch 35/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 109.1292 - mae: 109.1292
# Epoch 36/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 103.5289 - mae: 103.5289
# Epoch 37/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 98.4774 - mae: 98.4774
# Epoch 38/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 93.8570 - mae: 93.8570
# Epoch 39/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 89.6678 - mae: 89.6678
# Epoch 40/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 86.1824 - mae: 86.1824
# Epoch 41/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 83.1762 - mae: 83.1762
# Epoch 42/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 80.7635 - mae: 80.7635
# Epoch 43/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 78.7728 - mae: 78.7728
# Epoch 44/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 76.9886 - mae: 76.9886
# Epoch 45/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 75.2402 - mae: 75.2402
# Epoch 46/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 73.6205 - mae: 73.6205
# Epoch 47/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 72.2615 - mae: 72.2615
# Epoch 48/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 70.8427 - mae: 70.8427
# Epoch 49/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 69.5824 - mae: 69.5824
# Epoch 50/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 68.3848 - mae: 68.3848
# Epoch 51/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 67.2740 - mae: 67.2740
# Epoch 52/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 66.2750 - mae: 66.2750
# Epoch 53/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 65.3191 - mae: 65.3191
# Epoch 54/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 64.3684 - mae: 64.3684
# Epoch 55/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 63.4729 - mae: 63.4729
# Epoch 56/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 62.6417 - mae: 62.6417
# Epoch 57/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 61.8992 - mae: 61.8992
# Epoch 58/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 61.2738 - mae: 61.2738
# Epoch 59/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 60.6827 - mae: 60.6827
# Epoch 60/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 60.1385 - mae: 60.1385
# Epoch 61/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.5703 - mae: 59.5703
# Epoch 62/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 59.0480 - mae: 59.0480
# Epoch 63/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 58.5217 - mae: 58.5217
# Epoch 64/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 58.0487 - mae: 58.0487
# Epoch 65/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 57.5881 - mae: 57.5881
# Epoch 66/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 57.1507 - mae: 57.1507
# Epoch 67/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 56.7355 - mae: 56.7355
# Epoch 68/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 56.3643 - mae: 56.3643
# Epoch 69/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55.9334 - mae: 55.9334
# Epoch 70/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 55.5366 - mae: 55.5366
# Epoch 71/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 55.2469 - mae: 55.2469
# Epoch 72/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 54.8871 - mae: 54.8871
# Epoch 73/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 54.5749 - mae: 54.5749
# Epoch 74/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 54.2322 - mae: 54.2322
# Epoch 75/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.9040 - mae: 53.9040
# Epoch 76/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.6023 - mae: 53.6023
# Epoch 77/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.3107 - mae: 53.3107
# Epoch 78/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 53.0276 - mae: 53.0276
# Epoch 79/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.7941 - mae: 52.7941
# Epoch 80/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.5157 - mae: 52.5157
# Epoch 81/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.2780 - mae: 52.2780
# Epoch 82/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 52.0443 - mae: 52.0443
# Epoch 83/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51.8277 - mae: 51.8277
# Epoch 84/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51.5944 - mae: 51.5944
# Epoch 85/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51.3907 - mae: 51.3907
# Epoch 86/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 51.2167 - mae: 51.2167
# Epoch 87/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 51.0063 - mae: 51.0063
# Epoch 88/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.7502 - mae: 50.7502
# Epoch 89/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.6954 - mae: 50.6954
# Epoch 90/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.5554 - mae: 50.5554
# Epoch 91/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.4096 - mae: 50.4096
# Epoch 92/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50.2658 - mae: 50.2658
# Epoch 93/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 50.1310 - mae: 50.1310
# Epoch 94/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.9772 - mae: 49.9772
# Epoch 95/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.8426 - mae: 49.8426
# Epoch 96/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.7210 - mae: 49.7210
# Epoch 97/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.5973 - mae: 49.5973
# Epoch 98/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.4544 - mae: 49.4544
# Epoch 99/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.3622 - mae: 49.3622
# Epoch 100/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 49.2372 - mae: 49.2372
# Epoch 101/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 49.1273 - mae: 49.1273
# Epoch 102/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.9609 - mae: 48.9609
# Epoch 103/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.9126 - mae: 48.9126
# Epoch 104/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.8158 - mae: 48.8158
# Epoch 105/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.7238 - mae: 48.7238
# Epoch 106/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.6508 - mae: 48.6508
# Epoch 107/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.5879 - mae: 48.5879
# Epoch 108/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.4372 - mae: 48.4372
# Epoch 109/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 48.4130 - mae: 48.4130
# Epoch 110/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.3712 - mae: 48.3712
# Epoch 111/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.1535 - mae: 48.1535
# Epoch 112/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 48.1443 - mae: 48.1443
# Epoch 113/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.9714 - mae: 47.9714
# Epoch 114/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.9901 - mae: 47.9901
# Epoch 115/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.9240 - mae: 47.9240
# Epoch 116/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.8563 - mae: 47.8563
# Epoch 117/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.7424 - mae: 47.7424
# Epoch 118/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.7397 - mae: 47.7397
# Epoch 119/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.7056 - mae: 47.7056
# Epoch 120/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.6289 - mae: 47.6289
# Epoch 121/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.5824 - mae: 47.5824
# Epoch 122/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.5273 - mae: 47.5273
# Epoch 123/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.4746 - mae: 47.4746
# Epoch 124/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.4267 - mae: 47.4267
# Epoch 125/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.4493 - mae: 47.4493
# Epoch 126/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.3245 - mae: 47.3245
# Epoch 127/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.2909 - mae: 47.2909
# Epoch 128/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.3118 - mae: 47.3118
# Epoch 129/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.2031 - mae: 47.2031
# Epoch 130/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.1363 - mae: 47.1363
# Epoch 131/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 47.0256 - mae: 47.0256
# Epoch 132/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.1258 - mae: 47.1258
# Epoch 133/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 47.0394 - mae: 47.0394
# Epoch 134/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.9908 - mae: 46.9908
# Epoch 135/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.9582 - mae: 46.9582
# Epoch 136/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.9158 - mae: 46.9158
# Epoch 137/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.8908 - mae: 46.8908
# Epoch 138/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.8996 - mae: 46.8996
# Epoch 139/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.8069 - mae: 46.8069
# Epoch 140/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.7781 - mae: 46.7781
# Epoch 141/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.7014 - mae: 46.7014
# Epoch 142/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.6878 - mae: 46.6878
# Epoch 143/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.6691 - mae: 46.6691
# Epoch 144/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.6236 - mae: 46.6236
# Epoch 145/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.5907 - mae: 46.5907
# Epoch 146/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.5913 - mae: 46.5913
# Epoch 147/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.4982 - mae: 46.4982
# Epoch 148/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.5064 - mae: 46.5064
# Epoch 149/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.4559 - mae: 46.4559
# Epoch 150/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.4371 - mae: 46.4371
# Epoch 151/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.3640 - mae: 46.3640
# Epoch 152/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.3945 - mae: 46.3945
# Epoch 153/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.3138 - mae: 46.3138
# Epoch 154/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.3051 - mae: 46.3051
# Epoch 155/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.2483 - mae: 46.2483
# Epoch 156/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.2409 - mae: 46.2409
# Epoch 157/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 46.1996 - mae: 46.1996
# Epoch 158/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.1680 - mae: 46.1680
# Epoch 159/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.1133 - mae: 46.1133
# Epoch 160/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.1238 - mae: 46.1238
# Epoch 161/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.0880 - mae: 46.0880
# Epoch 162/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 46.0452 - mae: 46.0452
# Epoch 163/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.9620 - mae: 45.9620
# Epoch 164/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.9812 - mae: 45.9812
# Epoch 165/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.9316 - mae: 45.9316
# Epoch 166/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.9382 - mae: 45.9382
# Epoch 167/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.8942 - mae: 45.8942
# Epoch 168/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.8371 - mae: 45.8371
# Epoch 169/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.8294 - mae: 45.8294
# Epoch 170/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.7860 - mae: 45.7860
# Epoch 171/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.8146 - mae: 45.8146
# Epoch 172/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.7632 - mae: 45.7632
# Epoch 173/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.7130 - mae: 45.7130
# Epoch 174/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.7246 - mae: 45.7246
# Epoch 175/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.6795 - mae: 45.6795
# Epoch 176/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.7239 - mae: 45.7239
# Epoch 177/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.6283 - mae: 45.6283
# Epoch 178/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.5656 - mae: 45.5656
# Epoch 179/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.5612 - mae: 45.5612
# Epoch 180/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.5478 - mae: 45.5478
# Epoch 181/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.5213 - mae: 45.5213
# Epoch 182/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.5134 - mae: 45.5134
# Epoch 183/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.5048 - mae: 45.5048
# Epoch 184/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.4206 - mae: 45.4206
# Epoch 185/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.4623 - mae: 45.4623
# Epoch 186/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.4348 - mae: 45.4348
# Epoch 187/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.4325 - mae: 45.4325
# Epoch 188/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.3775 - mae: 45.3775
# Epoch 189/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.4212 - mae: 45.4212
# Epoch 190/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.3350 - mae: 45.3350
# Epoch 191/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.3117 - mae: 45.3117
# Epoch 192/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2867 - mae: 45.2867
# Epoch 193/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.3421 - mae: 45.3421
# Epoch 194/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.2577 - mae: 45.2577
# Epoch 195/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2831 - mae: 45.2831
# Epoch 196/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2488 - mae: 45.2488
# Epoch 197/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.2155 - mae: 45.2155
# Epoch 198/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.2002 - mae: 45.2002
# Epoch 199/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 45.2174 - mae: 45.2174
# Epoch 200/200
# 24/24 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 45.2102 - mae: 45.2102

# %%
tf_model2.evaluate(X_test_standard, y_test)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - loss: 49.8624 - mae: 49.8624
# [48.69206237792969, 48.69206237792969]

# %%
pd.DataFrame(train_history.history).plot()
plt.ylabel('loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')
