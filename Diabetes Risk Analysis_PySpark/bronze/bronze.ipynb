# %% [markdown]
# ## Read and save raw data

# %%
display(spark.sql("SHOW TABLES IN landing"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>database</th><th>tableName</th><th>isTemporary</th></tr></thead><tbody><tr><td>landing</td><td>prediabetes</td><td>false</td></tr></tbody></table></div>

# %%
raw_df = spark.table("landing.prediabetes") 

raw_df.write.format("delta") \
    .mode("overwrite") \
    .saveAsTable("bronze.prediabetes_raw")

print("Completed!")
# Out:
# Completed!
