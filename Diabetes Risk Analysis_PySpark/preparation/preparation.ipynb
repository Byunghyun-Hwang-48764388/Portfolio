# %%
# %sql
CREATE DATABASE IF NOT EXISTS landing 
COMMENT 'Raw ingestion area for source data files';

CREATE DATABASE IF NOT EXISTS bronze 
COMMENT 'Raw data from landing area with original structure';

CREATE DATABASE IF NOT EXISTS silver 
COMMENT 'Cleaned, filtered, and joined data for analysis';

CREATE DATABASE IF NOT EXISTS gold 
COMMENT 'Aggregated business-level data for reporting';
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>
